# %% [markdown]
# # DCF Part 2: Historical Analysis
#
# In this notebook, we do historical analysis of our target firm. This is all backward looking.
#
# The primary goal is to help us understand the firm's context which in turn helps us understand how to best make projections into the future. This is not the only analysis we need, but we do need it.
#
# The focus will be on key valuation metrics:
# * Growth Rates
# * Margins
# * Reinvestment
#
# ## Plan
#
# 1. Get Income Statement data: Revenue and EBIT. Compute growth rates in both for as long a history as we can (4 years for Yahoo)
# 2. Compute EBIT Margin (EBIT/Revenue) and Gross Margin (Gross Profit/Revenue)
# 3. Get Balance Sheet data to compute NWC and Change in NWC
# 4. Get Statement of Cash Flows to get Capital Expenditures and Depreciation & Amortization.
# 5. Compute Reinvestment = CapEx - D&A + Change in NWC
# 6. Compute FCF, NOPAT and Reinvestment Rate = Reinvestment/NOPAT
#
#
# This is our in-class project that we will work on progressively through the mod.
#
# Expectations:
# 1. Notebook is clean and neat, with no repeated code. It has clearly labeled sections for inputs/imports at the beginning. Code is sufficiently commented to demonstrate your understanding of the code and help you or anyone else who may use this code later. All numbers should be formatted so they are readable (so, use commas with large numbers, only a few decimal points).
# 2. All calculations are correct and all discussion questions are answered completely but concisely, demonstrating a depth of understanding.
#
# Workflow:
# 1. Notebooks are inherently experimental and allow you to try things, however that requires some good habits
# 2. Once you are "done" in any sense, you always need to "clean up" your notebook to make it presentable. You'd do the same in Excel - you've tried lots of things, etc. but before you present it, you clean it up.
# 3. Finally, restart the Runtime/Kernel and run it cleanly all the way top to bottom one time.
#
# Then, its ready to go.

# %% [markdown]
# ## 1 Always put Imports and Installs at the beginning
#
# And only put them in once.
#
# Set display options here if you are using them.
#
# Set API Keys here if you need them.

# %%
# necessary imports
import pandas as pd
import numpy as np
import yfinance as yf
import statsmodels.api as sm
from datetime import datetime
from google.colab import userdata

# %%
# Format setting for the model - tame the decimals!
pd.options.display.float_format = '{:,.2f}'.format

# %%
# Set Ticker we are modeling
ticker_symbol = 'MSFT'

eff_tax_rate = 0.19 # need to set Effective Tax Rate, validate
marg_tax_rate = 0.25

# this is what we divide numbers by, 1000000 is $M
scale_factor = 1000000
scale_name = 'M'

# %% [markdown]
# ## 2 Get Income Statement Data

# %%
# Create a Ticker object
ticker = yf.Ticker(ticker_symbol)

# Get annual income statement data, transpose and sort so numeric index is in correct order.
# OUTPUT should have 4 rows, one for each date and column names across the top are IS fields
income_statement = ticker.financials.T.sort_index()

# %%
# lots of data in this one, so print it out with .info()
income_statement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4 entries, 2022-06-30 to 2025-06-30
# Data columns (total 47 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Tax Effect Of Unusual Items                                 4 non-null      float64
#  1   Tax Rate For Calcs                                          4 non-null      float64
#  2   Normalized EBITDA                                           4 non-null      float64
#  3   Total Unusual Items                                         4 non-null      float64
#  4   Total Unusual Items Excluding Goodwill                      4 non-null      float64
#  5   Net Income From Continuing Operation Net Minority Interest  4 non-null      float64
#  6   Reconciled Depreciation                                     4 non-null      float64
#  7   Reconciled Cost Of Revenue                                  4 non-null      float64
#  8   EBITDA                                                      4 non-null      float64
#  9   EBIT                                                        4 non-null      float64
#  10  Net Interest Income                                         4 non-null      float64
#  11  Interest Expense                                            4 non-null      float64
#  12  Interest Income                                             4 non-null      float64
#  13  Normalized Income                                           4 non-null      float64
#  14  Net Income From Continuing And Discontinued Operation       4 non-null      float64
#  15  Total Expenses                                              4 non-null      float64
#  16  Total Operating Income As Reported                          4 non-null      float64
#  17  Diluted Average Shares                                      4 non-null      float64
#  18  Basic Average Shares                                        4 non-null      float64
#  19  Diluted EPS                                                 4 non-null      float64
#  20  Basic EPS                                                   4 non-null      float64
#  21  Diluted NI Availto Com Stockholders                         4 non-null      float64
#  22  Net Income Common Stockholders                              4 non-null      float64
#  23  Net Income                                                  4 non-null      float64
#  24  Net Income Including Noncontrolling Interests               4 non-null      float64
#  25  Net Income Continuous Operations                            4 non-null      float64
#  26  Tax Provision                                               4 non-null      float64
#  27  Pretax Income                                               4 non-null      float64
#  28  Other Income Expense                                        4 non-null      float64
#  29  Other Non Operating Income Expenses                         4 non-null      float64
#  30  Special Income Charges                                      4 non-null      float64
#  31  Write Off                                                   4 non-null      float64
#  32  Gain On Sale Of Security                                    4 non-null      float64
#  33  Net Non Operating Interest Income Expense                   4 non-null      float64
#  34  Interest Expense Non Operating                              4 non-null      float64
#  35  Interest Income Non Operating                               4 non-null      float64
#  36  Operating Income                                            4 non-null      float64
#  37  Operating Expense                                           4 non-null      float64
#  38  Research And Development                                    4 non-null      float64
#  39  Selling General And Administration                          4 non-null      float64
#  40  Selling And Marketing Expense                               4 non-null      float64
#  41  General And Administrative Expense                          4 non-null      float64
#  42  Other Gand A                                                4 non-null      float64
#  43  Gross Profit                                                4 non-null      float64
#  44  Cost Of Revenue                                             4 non-null      float64
#  45  Total Revenue                                               4 non-null      float64
#  46  Operating Revenue                                           4 non-null      float64
# dtypes: float64(47)
# memory usage: 1.5 KB

# %%
# print key columns: Total Revenue, EBIT, Gross Profit
income_statement[['Total Revenue', 'EBIT', 'Gross Profit']]/scale_factor
# Out:
#             Total Revenue       EBIT  Gross Profit
# 2022-06-30     198,270.00  85,779.00    135,620.00
# 2023-06-30     211,915.00  91,279.00    146,052.00
# 2024-06-30     245,122.00 110,722.00    171,008.00
# 2025-06-30     281,724.00 126,012.00    193,893.00

# %% [markdown]
# ### Compute Growth Rates and Margins

# %%
# Calculate Gross Margin
gross_margin = (income_statement['Gross Profit'] / income_statement['Total Revenue'])

# Calculate EBIT Margin
ebit_margin = (income_statement['EBIT'] / income_statement['Total Revenue'])

# Compute Revenue Growth, EBIT Growth
revenue_growth = income_statement['Total Revenue'].pct_change()
ebit_growth = income_statement['EBIT'].pct_change()

# Create a dataframe called df_stats that has the following:
# Revenue Growth, EBIT Growth, Gross Margin, EBIT Margin, Tax Rate for Calcs (eff tax rate) - column names. Rows are dates (year)
# How you do this may vary depending on how you did things above
df_stats = pd.DataFrame({
    'Revenue Growth': revenue_growth,
    'EBIT Growth': ebit_growth,
    'Gross Margin': gross_margin,
    'EBIT Margin': ebit_margin,
    'Tax Rate for Calcs': income_statement['Tax Rate For Calcs']
})
# print it out
display(df_stats)
# Out:
#             Revenue Growth  EBIT Growth  Gross Margin  EBIT Margin  \
# 2022-06-30             NaN          NaN          0.68         0.43
# 2023-06-30            0.07         0.06          0.69         0.43
# 2024-06-30            0.16         0.21          0.70         0.45
# 2025-06-30            0.15         0.14          0.69         0.45
#
#             Tax Rate for Calcs
# 2022-06-30                0.13
# 2023-06-30                0.19
# 2024-06-30                0.18
# 2025-06-30                0.18

# %% [markdown]
# ## 3 Get Balance Sheet Data

# %%
# Repeat the above but with the balance sheet - get it, transpose so dates are rows, columns are fields
balance_sheet = ticker.balance_sheet.T.sort_index()

# %%
# again use .info() so you can see what you have
balance_sheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2021-06-30 to 2025-06-30
# Data columns (total 78 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Ordinary Shares Number                                  4 non-null      float64
#  1   Share Issued                                            4 non-null      float64
#  2   Net Debt                                                4 non-null      float64
#  3   Total Debt                                              4 non-null      float64
#  4   Tangible Book Value                                     4 non-null      float64
#  5   Invested Capital                                        4 non-null      float64
#  6   Working Capital                                         4 non-null      float64
#  7   Net Tangible Assets                                     4 non-null      float64
#  8   Capital Lease Obligations                               4 non-null      float64
#  9   Common Stock Equity                                     4 non-null      float64
#  10  Total Capitalization                                    4 non-null      float64
#  11  Total Equity Gross Minority Interest                    4 non-null      float64
#  12  Stockholders Equity                                     4 non-null      float64
#  13  Gains Losses Not Affecting Retained Earnings            4 non-null      float64
#  14  Other Equity Adjustments                                4 non-null      float64
#  15  Retained Earnings                                       4 non-null      float64
#  16  Capital Stock                                           4 non-null      float64
#  17  Common Stock                                            4 non-null      float64
#  18  Total Liabilities Net Minority Interest                 4 non-null      float64
#  19  Total Non Current Liabilities Net Minority Interest     4 non-null      float64
#  20  Other Non Current Liabilities                           4 non-null      float64
#  21  Tradeand Other Payables Non Current                     4 non-null      float64
#  22  Non Current Deferred Liabilities                        4 non-null      float64
#  23  Non Current Deferred Revenue                            4 non-null      float64
#  24  Non Current Deferred Taxes Liabilities                  4 non-null      float64
#  25  Long Term Debt And Capital Lease Obligation             4 non-null      float64
#  26  Long Term Capital Lease Obligation                      4 non-null      float64
#  27  Long Term Debt                                          4 non-null      float64
#  28  Current Liabilities                                     4 non-null      float64
#  29  Other Current Liabilities                               4 non-null      float64
#  30  Current Deferred Liabilities                            4 non-null      float64
#  31  Current Deferred Revenue                                4 non-null      float64
#  32  Current Debt And Capital Lease Obligation               4 non-null      float64
#  33  Current Debt                                            4 non-null      float64
#  34  Other Current Borrowings                                3 non-null      float64
#  35  Commercial Paper                                        3 non-null      float64
#  36  Pensionand Other Post Retirement Benefit Plans Current  4 non-null      float64
#  37  Payables And Accrued Expenses                           4 non-null      float64
#  38  Payables                                                4 non-null      float64
#  39  Total Tax Payable                                       4 non-null      float64
#  40  Income Tax Payable                                      4 non-null      float64
#  41  Accounts Payable                                        4 non-null      float64
#  42  Total Assets                                            4 non-null      float64
#  43  Total Non Current Assets                                4 non-null      float64
#  44  Other Non Current Assets                                4 non-null      float64
#  45  Financial Assets                                        4 non-null      float64
#  46  Investments And Advances                                4 non-null      float64
#  47  Investmentin Financial Assets                           4 non-null      float64
#  48  Available For Sale Securities                           2 non-null      float64
#  49  Long Term Equity Investment                             4 non-null      float64
#  50  Goodwill And Other Intangible Assets                    4 non-null      float64
#  51  Other Intangible Assets                                 4 non-null      float64
#  52  Goodwill                                                4 non-null      float64
#  53  Net PPE                                                 4 non-null      float64
#  54  Accumulated Depreciation                                4 non-null      float64
#  55  Gross PPE                                               4 non-null      float64
#  56  Leases                                                  4 non-null      float64
#  57  Other Properties                                        4 non-null      float64
#  58  Machinery Furniture Equipment                           4 non-null      float64
#  59  Buildings And Improvements                              4 non-null      float64
#  60  Land And Improvements                                   4 non-null      float64
#  61  Properties                                              4 non-null      float64
#  62  Current Assets                                          4 non-null      float64
#  63  Other Current Assets                                    4 non-null      float64
#  64  Hedging Assets Current                                  4 non-null      float64
#  65  Inventory                                               4 non-null      float64
#  66  Finished Goods                                          4 non-null      float64
#  67  Work In Process                                         4 non-null      float64
#  68  Raw Materials                                           4 non-null      float64
#  69  Receivables                                             4 non-null      float64
#  70  Accounts Receivable                                     4 non-null      float64
#  71  Allowance For Doubtful Accounts Receivable              4 non-null      float64
#  72  Gross Accounts Receivable                               4 non-null      float64
#  73  Cash Cash Equivalents And Short Term Investments        4 non-null      float64
#  74  Other Short Term Investments                            4 non-null      float64
#  75  Cash And Cash Equivalents                               4 non-null      float64
#  76  Cash Equivalents                                        4 non-null      float64
#  77  Cash Financial                                          4 non-null      float64
# dtypes: float64(78)
# memory usage: 3.1 KB

# %%
# print key columns for Non-Cash NWC: Current Assets, Liabilities, Cash, Current Debt
display(balance_sheet[['Current Assets', 'Current Liabilities', 'Cash And Cash Equivalents', 'Current Debt']]/scale_factor)
# Out:
#             Current Assets  Current Liabilities  Cash And Cash Equivalents  \
# 2021-06-30             NaN                  NaN                        NaN
# 2022-06-30      169,684.00            95,082.00                  13,931.00
# 2023-06-30      184,257.00           104,149.00                  34,704.00
# 2024-06-30      159,734.00           125,286.00                  18,315.00
# 2025-06-30      191,131.00           141,218.00                  30,242.00
#
#             Current Debt
# 2021-06-30           NaN
# 2022-06-30      2,749.00
# 2023-06-30      5,247.00
# 2024-06-30      8,942.00
# 2025-06-30      2,999.00

# %% [markdown]
# ### Compute NWC and Change in NWC

# %%
# Adjust Current Assets by subtracting Cash
adjusted_current_assets = balance_sheet['Current Assets'] - balance_sheet['Cash Cash Equivalents And Short Term Investments']

# Adjust Current Liabilities by subtracting Current Debt
adjusted_current_liabilities = balance_sheet['Current Liabilities'] - balance_sheet['Current Debt And Capital Lease Obligation']

# Calculate NWC = Adj CA - Adj CL
nwc = adjusted_current_assets - adjusted_current_liabilities

# Calculate the Change in NWC
change_in_nwc = nwc.diff()

# Create a new DataFrame with the required column
nwc_change_df = pd.DataFrame({'NWC': nwc,'Change in NWC': change_in_nwc})

# Display the new DataFrame
display(nwc_change_df/scale_factor)
# Out:
#                   NWC  Change in NWC
# 2021-06-30        NaN            NaN
# 2022-06-30 -27,398.00            NaN
# 2023-06-30 -25,901.00       1,497.00
# 2024-06-30 -32,141.00      -6,240.00
# 2025-06-30 -41,643.00      -9,502.00

# %% [markdown]
# ## 4 Get Statement of Cash Flows

# %%
# Repeat the above but with SCF
cash_flows = ticker.cashflow.T.sort_index()

# %%
# print the .info()
cash_flows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2021-06-30 to 2025-06-30
# Data columns (total 59 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Free Cash Flow                                  4 non-null      float64
#  1   Repurchase Of Capital Stock                     4 non-null      float64
#  2   Repayment Of Debt                               4 non-null      float64
#  3   Issuance Of Debt                                4 non-null      float64
#  4   Issuance Of Capital Stock                       4 non-null      float64
#  5   Capital Expenditure                             4 non-null      float64
#  6   End Cash Position                               4 non-null      float64
#  7   Beginning Cash Position                         4 non-null      float64
#  8   Effect Of Exchange Rate Changes                 4 non-null      float64
#  9   Changes In Cash                                 4 non-null      float64
#  10  Financing Cash Flow                             4 non-null      float64
#  11  Cash Flow From Continuing Financing Activities  4 non-null      float64
#  12  Net Other Financing Charges                     4 non-null      float64
#  13  Cash Dividends Paid                             4 non-null      float64
#  14  Common Stock Dividend Paid                      4 non-null      float64
#  15  Net Common Stock Issuance                       4 non-null      float64
#  16  Common Stock Payments                           4 non-null      float64
#  17  Common Stock Issuance                           4 non-null      float64
#  18  Net Issuance Payments Of Debt                   4 non-null      float64
#  19  Net Short Term Debt Issuance                    4 non-null      float64
#  20  Short Term Debt Issuance                        3 non-null      float64
#  21  Net Long Term Debt Issuance                     4 non-null      float64
#  22  Long Term Debt Payments                         4 non-null      float64
#  23  Long Term Debt Issuance                         4 non-null      float64
#  24  Investing Cash Flow                             4 non-null      float64
#  25  Cash Flow From Continuing Investing Activities  4 non-null      float64
#  26  Net Other Investing Changes                     4 non-null      float64
#  27  Net Investment Purchase And Sale                4 non-null      float64
#  28  Sale Of Investment                              4 non-null      float64
#  29  Purchase Of Investment                          4 non-null      float64
#  30  Net Business Purchase And Sale                  4 non-null      float64
#  31  Purchase Of Business                            4 non-null      float64
#  32  Net PPE Purchase And Sale                       4 non-null      float64
#  33  Purchase Of PPE                                 4 non-null      float64
#  34  Operating Cash Flow                             4 non-null      float64
#  35  Cash Flow From Continuing Operating Activities  4 non-null      float64
#  36  Change In Working Capital                       4 non-null      float64
#  37  Change In Other Working Capital                 4 non-null      float64
#  38  Change In Other Current Liabilities             4 non-null      float64
#  39  Change In Other Current Assets                  4 non-null      float64
#  40  Change In Payables And Accrued Expense          4 non-null      float64
#  41  Change In Payable                               4 non-null      float64
#  42  Change In Account Payable                       4 non-null      float64
#  43  Change In Tax Payable                           4 non-null      float64
#  44  Change In Income Tax Payable                    4 non-null      float64
#  45  Change In Inventory                             4 non-null      float64
#  46  Change In Receivables                           4 non-null      float64
#  47  Changes In Account Receivables                  4 non-null      float64
#  48  Stock Based Compensation                        4 non-null      float64
#  49  Unrealized Gain Loss On Investment Securities   4 non-null      float64
#  50  Asset Impairment Charge                         4 non-null      float64
#  51  Deferred Tax                                    4 non-null      float64
#  52  Deferred Income Tax                             4 non-null      float64
#  53  Depreciation Amortization Depletion             4 non-null      float64
#  54  Depreciation And Amortization                   4 non-null      float64
#  55  Depreciation                                    4 non-null      float64
#  56  Operating Gains Losses                          4 non-null      float64
#  57  Gain Loss On Investment Securities              4 non-null      float64
#  58  Net Income From Continuing Operations           4 non-null      float64
# dtypes: float64(59)
# memory usage: 2.3 KB

# %%
# print key columns - CapEx and D&A
display(cash_flows[['Capital Expenditure', 'Depreciation And Amortization']]/scale_factor)
# Out:
#             Capital Expenditure  Depreciation And Amortization
# 2021-06-30                  NaN                            NaN
# 2022-06-30           -23,886.00                      14,460.00
# 2023-06-30           -28,107.00                      13,861.00
# 2024-06-30           -44,477.00                      22,287.00
# 2025-06-30           -64,551.00                      34,153.00

# %%
# merge cash_flows and nwc_change_df on the date index
merged_df = cash_flows.join(nwc_change_df)

# Display the merged DataFrame, showing CapEx, D&A and Ch in NWC
display(merged_df[['Capital Expenditure', 'Depreciation And Amortization', 'Change in NWC']]/scale_factor)
# Out:
#             Capital Expenditure  Depreciation And Amortization  Change in NWC
# 2021-06-30                  NaN                            NaN            NaN
# 2022-06-30           -23,886.00                      14,460.00            NaN
# 2023-06-30           -28,107.00                      13,861.00       1,497.00
# 2024-06-30           -44,477.00                      22,287.00      -6,240.00
# 2025-06-30           -64,551.00                      34,153.00      -9,502.00

# %% [markdown]
# ### Compute Reinvestment and NOPAT

# %%
# Reverse the sign of the 'Capital Expenditure' to make it positive (my personal preference - optional)
merged_df['Capital Expenditure'] = -merged_df['Capital Expenditure']

# Calculate Reinvestment = CapEx - D&A + Ch in NWC
merged_df['Reinvestment'] = merged_df['Capital Expenditure']

# Extract the 'Reinvestment' column to a new DataFrame
reinvestment_df = merged_df[['Reinvestment']]/scale_factor

# Display the 'Reinvestment' DataFrame
reinvestment_df
# Out:
#             Reinvestment
# 2021-06-30           NaN
# 2022-06-30    -23,886.00
# 2023-06-30    -28,107.00
# 2024-06-30    -44,477.00
# 2025-06-30    -64,551.00

# %%
# Calculate NOPAT in the income statement dataframe
income_statement['NOPAT'] = income_statement['EBIT'] * (1 - income_statement['Tax Rate For Calcs'])

# Extract the 'NOPAT' column to a new DataFrame
nopat_df = income_statement[['NOPAT']]

# Display the 'NOPAT' DataFrame
display(nopat_df/scale_factor)
# Out:
#                 NOPAT
# 2022-06-30  74,541.95
# 2023-06-30  73,935.99
# 2024-06-30  90,570.60
# 2025-06-30 103,833.89

# %% [markdown]
# ## 5 Compute Reinvestment Rate

# %%
# Calculate Reinvestment Rate = Reinvestment/NOPAT

# merge in nopat_df and reinvestment_df (I kept it all in nopat_df)
reinvestment_rate_df = nopat_df.merge(reinvestment_df, left_index=True, right_index=True)

# compute reinvestment rate
reinvestment_rate_df['Reinvestment Rate'] = reinvestment_rate_df['Reinvestment'] / reinvestment_rate_df['NOPAT']

# Now, let's display the updated DataFrame with all the required information
display(reinvestment_rate_df.style.format({
    'NOPAT': lambda x: f'{x/scale_factor:,.2f}',
    'Reinvestment': lambda x: f'{x/scale_factor:,.2f}',
    'Reinvestment Rate': '{:.2%}'.format
}))
# Out:
# <style type="text/css">
# </style>
# <table id="T_eec92" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eec92_level0_col0" class="col_heading level0 col0" >NOPAT</th>
#       <th id="T_eec92_level0_col1" class="col_heading level0 col1" >Reinvestment</th>
#       <th id="T_eec92_level0_col2" class="col_heading level0 col2" >Reinvestment Rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eec92_level0_row0" class="row_heading level0 row0" >2022-06-30 00:00:00</th>
#       <td id="T_eec92_row0_col0" class="data row0 col0" >74,541.95</td>
#       <td id="T_eec92_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_eec92_row0_col2" class="data row0 col2" >nan%</td>
#     </tr>
#     <tr>
#       <th id="T_eec92_level0_row1" class="row_heading level0 row1" >2023-06-30 00:00:00</th>
#       <td id="T_eec92_row1_col0" class="data row1 col0" >73,935.99</td>
#       <td id="T_eec92_row1_col1" class="data row1 col1" >15,743.00</td>
#       <td id="T_eec92_row1_col2" class="data row1 col2" >21.29%</td>
#     </tr>
#     <tr>
#       <th id="T_eec92_level0_row2" class="row_heading level0 row2" >2024-06-30 00:00:00</th>
#       <td id="T_eec92_row2_col0" class="data row2 col0" >90,570.60</td>
#       <td id="T_eec92_row2_col1" class="data row2 col1" >15,950.00</td>
#       <td id="T_eec92_row2_col2" class="data row2 col2" >17.61%</td>
#     </tr>
#     <tr>
#       <th id="T_eec92_level0_row3" class="row_heading level0 row3" >2025-06-30 00:00:00</th>
#       <td id="T_eec92_row3_col0" class="data row3 col0" >103,833.89</td>
#       <td id="T_eec92_row3_col1" class="data row3 col1" >20,896.00</td>
#       <td id="T_eec92_row3_col2" class="data row3 col2" >20.12%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 6 Final Result

# %%
# now merge in the new Reinvestment Rate column into df_stats
df_stats = df_stats.merge(reinvestment_rate_df['Reinvestment Rate'], left_index=True, right_index=True)

df_stats
# Out:
#             Revenue Growth  EBIT Growth  Gross Margin  EBIT Margin  \
# 2022-06-30             NaN          NaN          0.68         0.43
# 2023-06-30            0.07         0.06          0.69         0.43
# 2024-06-30            0.16         0.21          0.70         0.45
# 2025-06-30            0.15         0.14          0.69         0.45
#
#             Tax Rate for Calcs  Reinvestment Rate
# 2022-06-30                0.13                NaN
# 2023-06-30                0.19               0.21
# 2024-06-30                0.18               0.18
# 2025-06-30                0.18               0.20

# %% [markdown]
# ## Homework
#
# Compute EBITDA Margin
#
# Output is a dataframe with a column called "EBITDA Margin" (there can be other columns also, but be sure to show this one by itself)

# %%
# Compute EBITDA Margin
ebitda_margin = income_statement['EBITDA'] / income_statement['Total Revenue']

# Create a DataFrame with the EBITDA Margin
ebitda_margin_df = pd.DataFrame({'EBITDA Margin': ebitda_margin})

# Display the DataFrame
display(ebitda_margin_df)
# Out:
#             EBITDA Margin
# 2022-06-30           0.51
# 2023-06-30           0.50
# 2024-06-30           0.54
# 2025-06-30           0.57
